# %% [markdown]
# # Medical Cost Prediction

# %% [markdown]
# ### Importing Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
file = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv')

# %%
df= pd.DataFrame(file)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# ##### Charges is Dependant (Y) variable

# %% [markdown]
# ### Handelling Null Values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### Label Encoding

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [raw]
# sex, region, smoker need to converted into integers

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE= LabelEncoder()

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [raw]
# 0=female, 1=male

# %%
df['sex']=LE.fit_transform(df['sex'])

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [raw]
# 0=ne, 1=nw, 2=se, 3=sw

# %%
df['region']=LE.fit_transform(df['region'])

# %%
df['smoker'].unique()
# Out:
# array([1, 0])

# %% [raw]
# 0=no, 1=yes

# %%
df['smoker']=LE.fit_transform(df['smoker'])

# %% [markdown]
# #### obs -: Encoding Applies with ascending order of alphabets

# %% [raw]
# eg. 'f'emale=0, 'm'ale=1

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Data Visualization

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
sns.regplot(df['age'],df['charges'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
# as age increases charges also positively increases

# %%
sns.scatterplot(df['age'],df['charges'],hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.regplot(df['bmi'],df['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
# as bmi increases charges increases

# %%
sns.countplot(df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
# males are slightly more than females

# %%
sns.countplot(df['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
df['smoker'].value_counts()
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
#huge diffeerence betn smokers and non smokers (non-smokers>smokers)

# %%
sns.barplot(df['children'],df['age'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='age'>

# %%
# there is no fixed relation between age and present children

# %%
sns.barplot(df['smoker'],df['age'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='age'>

# %%
sns.barplot(df['region'],df['children'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='children'>

# %%
# north west's people have more no. of childrens than others

# %%
sns.barplot(df['age'],df['charges'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
# as age increases charges increases

# %%
sns.distplot(df['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
sns.distplot(df['charges'])
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Density'>

# %%
# majority of charges are taken within 0-20000

# %%
sns.boxplot(df['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.boxplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# outliers are detected in bmi

# %%
sns.pairplot(df)

# %% [markdown]
# ## Summary Stats

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %% [raw]
# obs :
#     1. mean > median in most of the features/columns therefore most of the columns are right skewed
#     2. std is higher in age but by observing boxplot outliers have not seen
#     3. difference between 75th % and max is almost double there there should outliers in bmi

# %% [markdown]
# ## EDA Process

# %% [markdown]
# #### Removing skewness

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %%
# no huge skewness is seen in variables like bmi

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Removing Outliers

# %%
from scipy.stats import zscore

# %%
z= np.abs(zscore(df))

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1309 rows x 7 columns]

# %% [markdown]
# ### Correlational Test

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df1.drop('region',axis=1,inplace=True)

# %%
df1
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       1  16884.92400
# 1      18    1  33.770         1       0   1725.55230
# 2      28    1  33.000         3       0   4449.46200
# 3      33    1  22.705         0       0  21984.47061
# 4      32    1  28.880         0       0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       0  10600.54830
# 1334   18    0  31.920         0       0   2205.98080
# 1335   18    0  36.850         0       0   1629.83350
# 1336   21    0  25.800         0       0   2007.94500
# 1337   61    0  29.070         0       1  29141.36030
#
# [1309 rows x 6 columns]

# %% [markdown]
# #### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
y.shape
# Out:
# (1338,)

# %%
def vif_cal():
    vif=pd.DataFrame()
    vif['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif['columns']=x.columns
    print(vif)

# %%
vif_cal()
# Out:
#          vif   columns
# 0   7.551348       age
# 1   2.001061       sex
# 2  10.371829       bmi
# 3   1.801245  children
# 4   1.256837    smoker
# 5   2.924528    region

# %% [markdown]
# #### Making Normal Distribution

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS= StandardScaler()

# %%
x = SS.fit_transform(x)

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=43)

# %%
x_train.shape
# Out:
# (936, 6)

# %%
y_train.shape
# Out:
# (936,)

# %%
y_test.shape
# Out:
# (402,)

# %%
x_test.shape
# Out:
# (402, 6)

# %% [markdown]
# #### Using Algorithms

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.747799091081303

# %%
lr.intercept_
# Out:
# 13041.602362498736

# %%
# coef means if x increase by 1 then how many y will increase
lr.coef_
# Out:
# array([3331.45942087,  -19.47581057, 1944.22934931,  637.79160789,
#        9467.58040953, -504.68196032])

# %%
col=df1.columns

# %%
list(zip(lr.coef_,col))
# Out:
# [(3331.459420865204, 'age'),
#  (-19.47581056590648, 'sex'),
#  (1944.2293493083414, 'bmi'),
#  (637.7916078876332, 'children'),
#  (9467.58040952746, 'smoker'),
#  (-504.6819603210796, 'charges')]

# %%
pred= lr.predict(x_test)

# %%
pred
# Out:
# array([ 8367.05929067,  6483.24182501,  3214.84016447, 14515.28575532,
#        27919.12941132, 10279.94330324, 10830.60625476,  7366.68223883,
#         9690.57497849,  1853.09801195, 26979.30395608, 24988.7509003 ,
#         9271.84112941,  9634.36994252,  2903.19263151,  5538.00669152,
#         3124.98983185, 26596.18487519,  7117.79854915,  4038.91018647,
#         5355.45335357, 11895.63088292,  2818.49466671, 11100.78300627,
#         6935.72191915,  7528.9901088 , 10857.30966944, 39443.85840772,
#         2712.55716578, 12182.20074921, 14416.21076666, 31557.47053204,
#        15206.86426936,  1739.98402163, 11833.42204104,  4253.82585621,
#         7756.03950818, 12411.01673485, 10297.35839273,  5615.13849861,
#        27676.06449535, 27799.59839235,  3957.34540565, 13684.59707244,
#        11219.50458144, 33582.22536378, 11672.09096459,  3451.54395487,
#        26816.8251407 ,  7298.63492411,  1446.25480472,  6504.08249691,
#         9016.39235262, 31827.63153491,  2524.02914181,  2082.93843869,
#         6675.62242704, 15641.43578209, 30688.5612626 , 10500.55005482,
#        32819.65986362,  4217.67277564, 11596.64830171, 11559.72136098,
#         7850.32931918,  9227.34740443, 30121.81809716,  2013.2811246 ,
#         8456.74845938, 12875.60525335, 12293.64892487, 29476.82526798,
#         8649.55610513, 12947.18946004, 11329.88721403,  4819.79695326,
#        12674.83043314,  8377.98188517, 10161.18457753, 28313.02042601,
#        14508.40013837,  5947.17188808,  2861.62964783, 35403.48133391,
#         1129.175517  , 29892.59584317, 15830.74135092,  9658.42356976,
#        36772.11789764, 26893.29924713,  5114.98905149, 34959.99846766,
#        34009.5823852 , 15920.79501855,  7806.36605272, 26947.40994679,
#        10599.38235735,  9552.18698897, 13444.99291369, 13024.27209358,
#          762.35501815, 26609.29607295,  8766.57929212, 14071.92187569,
#         3066.07973189, 10204.77217345,  3224.33137493, 10591.11215254,
#        10788.94815273,  9725.85275267, 36283.2088836 ,  4134.20061836,
#        10981.24171513, 10693.12573634, 31558.00189002, 12658.26597129,
#         3869.99657715, 14108.46004757,  7011.74497771,  3021.93538372,
#        -1297.82654569,  7469.23575   , 28341.69461335,  6086.51191053,
#        38074.12112611,  9412.24426947,  7656.33194019,  9423.54083173,
#         6222.43667081,  1716.791703  , 13269.75671946,  3284.02233753,
#        12528.46086257,  6439.36358153,  9090.64048039, 10541.66786876,
#        11249.72452056, 15428.31420353, 11834.3220671 , 13391.1409146 ,
#        13346.26954336, 30386.41243322,  4872.35140412,  9877.82730585,
#         9069.41494205,   934.53609699,  8715.72031333, 31344.72664067,
#         5749.61729148,  4127.32868532, 25593.46268127,  8844.48500746,
#        29417.27361766,  6576.85988951,  6756.459919  ,  3948.74762759,
#        28543.09698614, 26466.9520425 , 28659.28951041,  9969.63203598,
#         3543.82445254, 10241.78023475, 11078.93435745, 13529.90255802,
#        29470.86107899,  8340.57671049, 36279.42602961, 31330.80483386,
#         7631.42593446,  8905.70897709, 10138.17042449, 15342.69588702,
#         8706.69876743, 31318.81211928,  2305.25147324,  9876.46681114,
#        36397.0048926 ,  8240.05507982,  2786.52258883,  5675.59022307,
#        26510.71215075, 35734.03151643, 15075.98841404,  7261.72175629,
#        15029.50704343,  5277.92927592, 14265.24773304,  4814.80969365,
#        12436.17202038,  6458.21095452, 12603.44283193,  6215.30850359,
#        14717.37647465, 31525.97583672,  6848.02151326,  8244.73724434,
#        14194.49472781, 27230.59533266, 28186.298695  ,  5801.38895205,
#         6858.98170803, 10731.08564662, 13561.75703939, 30523.64416251,
#        11402.14927023,  9087.37215949, 10593.44132112, 10576.96951122,
#        12404.76257289, 14135.48116499,  8195.27730093,  9803.17398599,
#        12036.16135413, 26942.75071016,  7957.27771315,  5933.41433809,
#         4027.52797471, 33239.19140023, 13197.61867664,  9106.52494022,
#         2414.87931206,  5295.9098229 ,  8600.18293555,   303.93366292,
#         3723.89356099,  2473.43016471, 12309.10418845,  3571.1226214 ,
#        37917.65199478,  2503.43950056, 10029.0109491 ,  6436.94059572,
#        31290.15538335, 28537.13324688,  7015.49610955,  7806.67850385,
#        25671.01767061, 16026.14956344,  6521.21878505, 26033.7714455 ,
#        27762.39655267,  3434.36890119, 14681.58201487,  4540.70050371,
#         9736.1957151 ,  2780.60425563,  3263.01678229,  8934.05411328,
#         3951.89633534, 10795.57071698, 10214.83364328, 11044.54669789,
#        14355.57392222,  7194.4690362 ,  3237.17315023, 26395.4817957 ,
#        14623.91387272, 37602.78603   ,  8044.8768977 ,  6596.04399073,
#        11602.68315516, 10042.31651082, 13570.01957428,  3225.22135369,
#        13872.13017687,  7146.1371326 ,  5577.99884303, 30604.96531681,
#        30109.62420009, 15005.64096163,  8522.39445599,  1540.74028082,
#        33783.21146186, 39081.62634518,  2558.63655961, 15451.26711287,
#         9189.46381188,  8281.94541188, 12835.12266192, 27097.93041291,
#        37804.66376869, 35197.94583086, 37176.36730951,  4937.59265837,
#         4362.86024197,  9901.02886847,  8639.63610009, 12481.08996293,
#        36161.51071135, 30931.50521717,  8174.08478585, 38636.83108152,
#         1849.80869081, 10709.61150308,  6476.95791663,  9931.32817729,
#         6586.8033131 ,  4133.39458631,  9278.53983459, 15465.59563777,
#        34983.57502622,  5135.5476452 ,  9323.18511973, 10311.38945153,
#         8312.98026507, 12386.37073081,  7415.18867141, 33110.89812152,
#         9633.85540944,  8619.50585123,  3581.16798187, 34489.38931836,
#        16282.11332305, 13222.18073396,  5531.58742135,  7451.11696699,
#         8688.94035606, 11538.62068739,  2574.45869949,  5728.09527551,
#        16591.43886668, 29544.64587007,  8869.41595773,  9644.78935854,
#        30920.32548903,  6121.83957379, 39825.97731746, 11933.08460463,
#        15604.40515363,  4854.88036348,  6551.26621184, 32927.28695849,
#         5282.13499828, 11888.65122388,  3677.63890302, 16681.28960096,
#         6107.15776873, 27827.48297087,  5613.87949104, 37637.43845219,
#        12204.32299584,  4619.5683402 ,  7660.33432756,  2178.74533131,
#         5144.71043102,  8814.76362793, 13520.34880275, 11177.69711984,
#        33299.64307661, 11175.43632613,  8443.73874876,  8774.56091409,
#         9629.85302207,  5283.15809732,  6324.51324917,  4898.77426659,
#         6376.34947121, 13740.05274304,  6385.87890845,  2426.46575829,
#         9077.57585395, 15204.97241667, 34480.57308318, 31591.89794438,
#        16537.24130419, 13381.04723196, 13803.67412742, 38253.14264072,
#         9069.86280304, 34122.05545167,  7710.05822314, 33567.1309625 ,
#        34591.43484917,  3057.42528715, 36034.8886757 , 37933.81723167,
#        10678.35294116, 12674.4226388 , 11879.14511617, 33316.1117936 ,
#        11195.24470308, 14116.22164551,  2789.60264877, 38523.20085533,
#        30296.70293887, 13757.83430717, 14308.06285891,  1330.36468429,
#         6857.00389197,  1641.0028502 ,  5900.58903034,  4638.06342027,
#        12284.7386476 ,  6310.05182886, 13961.63718761,  9900.73126651,
#         7110.09245263, 10615.4155093 , 24785.67705958, 11496.51189821,
#        14016.98876883,  5538.37334295])

# %%
predicted_df=pd.DataFrame(pred)

# %%
predicted_df.head()
# Out:
#               0
# 0   8367.059291
# 1   6483.241825
# 2   3214.840164
# 3  14515.285755
# 4  27919.129411

# %%
lr.score(x_test,y_test)
# Out:
# 0.7497518500786089

# %% [markdown]
# #### Calculating Error

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print('mean squared error=',mean_squared_error(y_test,pred))
print('root mean squared error=',np.sqrt(mean_squared_error(y_test,pred)))
print('mean abs error=',mean_absolute_error(y_test,pred))
print('r2 score/performence score=',r2_score(y_test,pred))
# Out:
# mean squared error= 41183311.21316553
# root mean squared error= 6417.422474262196
# mean abs error= 4448.753507988243
# r2 score/performence score= 0.7497518500786089

# %% [markdown]
# #### Regularization

# %%
# to improve accuracy of model

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
lasso= Lasso(alpha=0.1)

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
lasso.score(x_train,y_train)
# Out:
# 0.7477990906256986

# %%
lasso_pred=lasso.predict(x_test)

# %%
r2_score(y_test,lasso_pred)
# Out:
# 0.7497503959268397

# %%
ridge=Ridge(alpha=0.001)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
ridge.score(x_train,y_train)
# Out:
# 0.7477990910804138

# %%
ridge_pred=ridge.predict(x_test)

# %%
r2_score(y_test,ridge_pred)
# Out:
# 0.7497517454961866

# %%
EN = ElasticNet(alpha=0.001)

# %%
EN.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.001)

# %%
enpred=EN.predict(x_test)

# %%
r2_score(y_test,enpred)
# Out:
# 0.7497027481867973

# %% [markdown]
# #### Using More algos

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
knn= KNeighborsRegressor()
dtc= DecisionTreeRegressor()
svr = SVR()

# %%
models = [knn,dtc,svr]

# %%
for i in models:
    i.fit(x_train,y_train)
    regressor_pred=i.predict(x_test)
    print('score of',i,i.score(x_train,y_train))
    print('mean squared error of',i,mean_squared_error(y_test,regressor_pred))
    print('root mean squared error of',i,np.sqrt(mean_squared_error(y_test,regressor_pred)))
    print('mean abs errorof',i,mean_absolute_error(y_test,regressor_pred))
    print('r2 score/performence of',i,r2_score(y_test,regressor_pred))
    print('\n')
# Out:
# score of KNeighborsRegressor() 0.8740002244269716
# mean squared error of KNeighborsRegressor() 34014079.99833165
# root mean squared error of KNeighborsRegressor() 5832.159119771309
# mean abs errorof KNeighborsRegressor() 3503.24555050995
# r2 score/performence of KNeighborsRegressor() 0.7933152934983145
#
#
# score of DecisionTreeRegressor() 0.9985810992373253
# mean squared error of DecisionTreeRegressor() 41726534.01879712
# root mean squared error of DecisionTreeRegressor() 6459.607884291207
# mean abs errorof DecisionTreeRegressor() 3117.1051929452738
# r2 score/performence of DecisionTreeRegressor() 0.7464509862553776
#
#
# score of SVR() -0.10754390827448024
# mean squared error of SVR() 195550667.6950058
# root mean squared error of SVR() 13983.94320980337
# mean abs errorof SVR() 9081.434388950694
# r2 score/performence of SVR() -0.18825299289980268

# %% [markdown]
# #### Ensemble methods

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,VotingRegressor

# %%
RF=RandomForestRegressor(random_state=42)
GB=GradientBoostingRegressor()
ADA=AdaBoostRegressor()

# %%
ensemble_algo=[RF,GB,ADA]

for i in ensemble_algo:
    i.fit(x_train,y_train)
    ensemble_algo_pred=i.predict(x_test)
    print('score of',i,i.score(x_train,y_train))
    print('mean squared error of',i,mean_squared_error(y_test,regressor_pred))
    print('root mean squared error of',i,np.sqrt(mean_squared_error(y_test,regressor_pred)))
    print('mean abs errorof',i,mean_absolute_error(y_test,regressor_pred))
    print('r2 score/performence of',i,r2_score(y_test,regressor_pred))
    print('\n')
# Out:
# score of RandomForestRegressor(random_state=42) 0.9784596385842156
# mean squared error of RandomForestRegressor(random_state=42) 195550667.6950058
# root mean squared error of RandomForestRegressor(random_state=42) 13983.94320980337
# mean abs errorof RandomForestRegressor(random_state=42) 9081.434388950694
# r2 score/performence of RandomForestRegressor(random_state=42) -0.18825299289980268
#
#
# score of GradientBoostingRegressor() 0.9164999311365091
# mean squared error of GradientBoostingRegressor() 195550667.6950058
# root mean squared error of GradientBoostingRegressor() 13983.94320980337
# mean abs errorof GradientBoostingRegressor() 9081.434388950694
# r2 score/performence of GradientBoostingRegressor() -0.18825299289980268
#
#
# score of AdaBoostRegressor() 0.8388302863032502
# mean squared error of AdaBoostRegressor() 195550667.6950058
# root mean squared error of AdaBoostRegressor() 13983.94320980337
# mean abs errorof AdaBoostRegressor() 9081.434388950694
# r2 score/performence of AdaBoostRegressor() -0.18825299289980268

# %% [markdown]
# ### Exporting Decision Tree Model

# %% [markdown]
# #### KNN have better aaccuracy of 79 %

# %%
import joblib

# %%
knn_obj= joblib.dump(knn,'DT-1(CostPred).obj')
